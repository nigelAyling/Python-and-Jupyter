# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Milestone Project 2 - Walkthrough Steps Workbook
# Below is a set of steps for you to follow to try to create the Blackjack Milestone Project game!

# %%
#Pauls branch (V3)

#>>SETUP
import random
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
         'Queen':10, 'King':10, 'Ace':11}

playing = True

#------------------------------------------------------------------

#-----------CLASS DEFINITIONS------------------------

class Card:
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
    def __str__(self):
        return self.rank + " of " + self.suit

#----------------------------------------------------------------
    
class Deck:
    
    def __init__(self):
        self.deck = []  # start with an empty list
      #  for suit in suits:
     #       for rank in ranks:
     #           self.deck.append(Card(suit,rank))


        self.deck.append(Card('Hearts','Three'))
        self.deck.append(Card('Hearts','Six') ) 
        self.deck.append(Card('Hearts','Three'))
        self.deck.append(Card('Hearts','Queen'))
        self.deck.append(Card('Hearts','Nine'))
        self.deck.append(Card('Hearts','Four') ) 
        self.deck.append(Card('Hearts','Jack'))
        self.deck.append(Card('Hearts','Seven'))
        self.deck.append(Card('Hearts','Nine'))
        self.deck.append(Card('Hearts','Ace'))                
        return
    
    def __str__(self):
        pack = ""
        for card in self.deck:
            pack = pack + str(card) +"\n"
        return pack

    def shuffle(self):
        random.shuffle(self.deck)
        
    def deal(self):
        return self.deck.pop()
    
#--------------------------------------------------------------------

class Hand:
    def __init__(self):
        self.hand = []  # start with an empty list as we did in the Deck class
        self.value = 0   # start with zero value
        self.aces = 0    # add an attribute to keep track of aces
        self.adjustement_applied = 0 # a running total of adjustmest applied for aces in hand
    
    def add_card(self,card):
    #card = output from new_deck.deal()
    #STEPS
        #for given card
        rank_of_card = card.rank
        value_of_card = values[card.rank]
        if card.rank == 'Ace':
            number_of_new_aces = 1
        else:
            number_of_new_aces = 0
    #update  
        #self.cards
        self.hand.append(card)
        #self.value
        self.value = self.value + value_of_card
        #self.aces
        self.aces = self.aces + number_of_new_aces

        pass
    
    def adjust_for_ace(self):
        #OUT OF SCOPE FIVE CARD TRICKS JUST TEST FOR NOT BUST
        #identify # of aces
        #reduce to max score that is below 21 (given number of aces)
        if self.value > 21:
            print ('Player has over 21 ')
            print ('Number of aces in hand ', self.aces)
            if self.aces == 1 and self.adjustement_applied <10: 
                self.value = self.value -10 
                self.adjustement_applied = 10 
                print('New Ace Found! Total score reduced by:', self.adjustement_applied)
            elif self.aces == 2 and self.adjustement_applied <20:
                self.value = self.value -10 
                self.adjustement_applied = 20 
            
            elif self.aces == 3 and self.adjustement_applied <30:
                self.value = self.value -10 
                self.adjustement_applied = 30 
        
            elif self.aces == 4 and self.adjustement_applied <40: 
                self.value = self.value -10 
                self.adjustement_applied = 40    
    
    def hand_is_bust(self):
        if self.value > 21:
            print ("you are bust")
            return True
        else:
            return False
        
    def player_is_playing(self,bust):
        if bust == True:
            return False
        else:
            return True
                    
    def __str__(self):
        hand = ""
        for card in self.hand:
            hand = hand + str(card) +"\n"
        return hand
    
#------------------------------------------------------------------    
    
class Chips:
    def __init__(self):
        self.total = 100  # total number of chips the play has
        self.bet = 0 #  Number of chips bet on that hand of the one and only bet per hand
        
    def win_bet(self):
        self.total = self.total + self.bet
    
    def lose_bet(self):
        self.total = self.total - self.bet

# %%
        
#--------------FUNCTIONS--------------------------

def take_bet(players_chips):
    valid_bet = False
    while valid_bet == False:
        try:
            bet_value = int(input('Place your bets!!'))
        except:
          print("An integer please")
        if bet_value > players_chips.total :
            print("You have ", players_chips.total,"please provide an amout less than this.")
        else:
            players_chips.total= players_chips.total - bet_value
            players_chips.bet = bet_value
            
            valid_bet = True
            print("You now have ", players_chips.total,"chips left to gamble with")
            print("")
            print("Bet Placed £", bet_value)

def hit(deck,hand):    
    #deal a card
    new_card = deck.deal()
    #check if they are bust
    hand.add_card(new_card)
    print ('New card:',new_card)
    print ('New score after new card:',players_hand.value)
    hand.adjust_for_ace()
    print ('Adjusted Score:',players_hand.value)
    
def deal_a_new_card():
    player_input =''
    answer_valid = False
    while answer_valid == False:
        player_input = input("Enter Y to hit")
        print('player inputed:', player_input)
        if player_input == 'Y':
            player_playing = True
            answer_valid = True
            print('player inputed Y')
            print ('------------------------------')
        elif  player_input == 'N':
            player_playing = False
            answer_valid = True
            print('player inputed N')
        else:
            print ('please enter Y or N')
            print('player inputed something else')
    return player_playing

def show_some(player,dealer):
    print (dealer.hand[0])
    print (player.hand)
    
def show_all(player,dealer):
    print (dealer.hand)
    print (player.hand) 
    
def print_players_cards(players_hand,player_playing, bust):
# Show cards (but keep one dealer card hidden)
        print('-----print_players_cards:')
        print('Players Turn', player_playing)
        print('Bust?:', bust)
        print("")
        print("----------------")
        print("PLAYER,S HAND")
        print("")
        print(players_hand)
        print("Score of hand = ",players_hand.value)
    
def print_dealers_cards(dealers_hand, dealers_bust):
# Show cards (but keep one dealer card hidden)
        print('-----print_dealers_cards:')
        print('Bust?:', dealers_bust)
        print("")
        print("----------------")
        print("DEALERS,S HAND")
        print("")
        print(dealers_hand)
        print("Score of hand = ",dealers_hand.value) 
    
def print_turn (players_hand, dealers_hand):
    print('-----print_turn:')
    print("MY FUNC")
    print("----------------")
    print("PLAYER,S HAND")
    print("")
    print(players_hand)
    print("Score of hand = ",players_hand.value)
    print("----------------")
    print("")
    print("----------------")
    print("DEALER,S HAND")
    print("")
    print(dealers_cards_list[0])
    print("")
    print("Score of hand = ",dealers_hand.value)
    print("----------------")

def player_wins (players_hand_value, players_bust, dealers_hand_value, dealers_bust):
    if players_bust:
        player_win = False
    elif dealers_bust:
        player_win = True
    elif players_hand_value > dealers_hand_value:
        player_win = True
    else:
        player_win = False
    print ('Player has won?  ',player_win)
    return result   

# our function to sellte WIP
def settle_bet(player_has_won,players_chips ):
    #players_chips.total
    #players_chips.bet
    
    if player_has_won:
        players_chips.total = players_chips.total + (2 * players_chips.bet)        
    print ('players chips after settlement: ', players_chips.total)

#-------------------------------------------------------------------------------

def player_wins (players_hand_value, players_bust, dealers_hand_value, dealers_bust):
    if players_bust:
        player_win = False
    elif dealers_bust:
        player_win = True
    elif players_hand_value > dealers_hand_value:
        player_win = True
    else:
        player_win = False
    print ('Player has won?  ',player_win)
    return player_win  
    
def dealer_wins():
    pass
    
def push():
    pass

# %%
while True:
#SETUP GAME
    print("Blackjack game starting")
    # Create & shuffle the deck 
    game_deck = Deck()
    game_deck.shuffle()
    players_hand = Hand()
    dealers_hand = Hand()
    # Set up the Player's chips
    players_chips = Chips()
    dealers_chips = Chips()   
    
    
#BET PLACED AND INITIAL CARDS DEALT
    # Prompt the Player for their bet
    take_bet(players_chips)
    # Deal two cards to each player
    for n in range (2):
        players_card = game_deck.deal()
        players_hand.add_card(players_card)
        dealers_card = game_deck.deal()
        dealers_hand.add_card(dealers_card)
    # Create a list of the dealers card to enable showing only the first card    
    dealers_cards_list = str(dealers_hand).split("\n")
    print_turn(players_hand, dealers_hand)
    

#PLAYER PLAYING UNTIL BUST OR STAND
    #setup Playing variables
    player_playing = True
    bust = False 
    
    while player_playing:  # recall this variable from our hit_or_stand function
        if deal_a_new_card() == False:
            break   
        hit(game_deck,players_hand)
        bust = players_hand.hand_is_bust()
        player_playing = players_hand.player_is_playing(bust)
        print_players_cards(players_hand,player_playing, bust)
        
    if bust == True:
            player_has_won = False
    else:
        player_playing == False
        
#DEALER TURN STARTS HERE        
    print ('the dealer is now playing')
    player_has_won = False
    if bust == False:
        dealers_bust = False
        #could be its own functions
        while dealers_hand.value < 17 and dealers_bust == False:
            print ('Dealer dealing another card to himself')
            dealers_card = game_deck.deal()
            dealers_hand.add_card(dealers_card)
            print_dealers_cards(dealers_hand, dealers_bust)
            if dealers_hand.value > 21:
                print ('Dealer has gone bust')
                dealers_bust = True
            # work out who has won   
            player_has_won = player_wins(players_hand.value, bust, dealers_hand.value, dealers_bust)
    else:
        player_has_won = False
        
#THE GAME HAS ENDED FINANCIAL SETTLEMENT
    print('Players Bank prior to settlement: ', players_chips.total)
    print('Player has won: ', player_has_won)
    settle_bet(player_has_won,players_chips )     


# Ask to play again


    break
# Out:
# Blackjack game starting
