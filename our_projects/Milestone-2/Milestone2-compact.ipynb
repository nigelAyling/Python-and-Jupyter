# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Milestone Project 2 - Walkthrough Steps Workbook
# Below is a set of steps for you to follow to try to create the Blackjack Milestone Project game!

# %%
import random

suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
         'Queen':10, 'King':10, 'Ace':11}

playing = True

#------------------------------------------------------------------

#-----------CLASS DEFINITIONS------------------------

class Card:
    
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank

    def __str__(self):
        return self.rank + " of " + self.suit

#----------------------------------------------------------------
    
class Deck:
    
    def __init__(self):
        self.deck = []  # start with an empty list
      #  for suit in suits:
     #       for rank in ranks:
     #           self.deck.append(Card(suit,rank))


        self.deck.append(Card('Hearts','Three'))
        self.deck.append(Card('Hearts','Six') ) 
        self.deck.append(Card('Hearts','Three'))
        self.deck.append(Card('Hearts','Queen'))
        self.deck.append(Card('Hearts','Nine'))
        self.deck.append(Card('Hearts','Four') ) 
        self.deck.append(Card('Hearts','Jack'))
        self.deck.append(Card('Hearts','Seven'))
        self.deck.append(Card('Hearts','Three'))
        self.deck.append(Card('Hearts','Ace'))                
        return
    
    def __str__(self):
        pack = ""
        for card in self.deck:
            pack = pack + str(card) +"\n"
        return pack

    def shuffle(self):
        random.shuffle(self.deck)
        
    def deal(self):
        return self.deck.pop()
    
#--------------------------------------------------------------------

class Hand:
    def __init__(self):
        self.hand = []  # start with an empty list as we did in the Deck class
        self.value = 0   # start with zero value
        self.aces = 0    # add an attribute to keep track of aces
    
    def add_card(self,card):
    #card = output from new_deck.deal()
    #STEPS
        #for given card
        rank_of_card = card.rank
        value_of_card = values[card.rank]
        if card.rank == 'Ace':
            number_of_new_aces = 1
        else:
            number_of_new_aces = 0
    #update  
        #self.cards
        self.hand.append(card)
        #self.value
        self.value = self.value + value_of_card
        #self.aces
        self.aces = self.aces + number_of_new_aces

        pass
    
    def adjust_for_ace(self):
        #OUT OF SCOPE FIVE CARD TRICKS JUST TEST FOR NOT BUST
        #identify # of aces
        #reduce to max score that is below 21 (given number of aces)
        print ('>>adjust_for_ace: Prior to ran: hand.value: ', players_hand.value)
        if self.value > 21:
            print ('>>adjust_for_ace: After Ran selve.value>21 hand.value: ', players_hand.value)
            if self.aces == 1:
                
                self.value = self.value -10
                aces = 0
                
                print ("Hand has 1 new ace so subtract 10")
            elif self.new_aces == 2:
                if self.value -10 > 21:
                    self.value = self.value -20
                    print ("Hand has 2 ace so subtract 20")                
                else:
                    self.value = self.value -10
            elif self.aces == 3:
                if self.value-20 > 21:
                    self.value = self.value -30
                elif self.value -10 > 21:
                    self.value = self.value -20
                else:
                    self.value = self.value -10
        else:
            self.value == self.value
        print ('>>adjust_for_ace: After Ran else hand.value: ', players_hand.value)
                    
    def __str__(self):
        hand = ""
        for card in self.hand:
            hand = hand + str(card) +"\n"
        return hand
    
#------------------------------------------------------------------    
    
class Chips:
    def __init__(self):
        self.total = 100  # total number of chips the play has
        self.bet = 0 #  Number of chips bet on that hand of the one and only bet per hand
        
    def win_bet(self):
        self.total = self.total + self.bet
    
    def lose_bet(self):
        self.total = self.total - self.bet
        
#--------------------------------------------------------------------------

#--------------FUNCTIONS--------------------------

def take_bet():
    try:
        bet_value = int(input('Place your bets!!'))
        return (bet_value)
    except:
      print("An integer please")
    
#-----------------------------------------------------------------------------

def hit(deck,hand):    
    #deal a card
    new_card = deck.deal()
    #check if they are bust
    hand.add_card(new_card)
    print ('HIT > New score after new card:',players_hand.value)
    hand.adjust_for_ace()
    print ('HIT > after Adjust for Ace:',players_hand.value)
    
#-----------------------------------------------------------------------------

def hit_or_stand(deck,hand):
    global playing  # to control an upcoming while loop
    if playing == True:
            hit(deck,hand)
            print ('---->Hit_or_stand: hand.value', hand.value)
    else:
        playing = False
        
#------------------------------------------------------------------------------

def show_some(player,dealer):
    print (dealer.hand[0])
    print (player.hand)
    
def show_all(player,dealer):
    print (dealer.hand)
    print (player.hand)
    pass

#-------------------------------------------------------------------------------

def player_busts():
    pass

def player_wins():
    pass

def dealer_busts():
    pass
    
def dealer_wins():
    pass
    
def push():
    pass

# %%
while True:
    # Print an opening statement
    print("Blackjack game starting")
    
    # Create & shuffle the deck 

    game_deck = Deck()
    #game_deck.shuffle()
    players_hand = Hand()
    dealers_hand = Hand()
    
    # Deal two cards to each player
  
    for n in range (2):
        players_card = game_deck.deal()
        players_hand.add_card(players_card)
        dealers_card = game_deck.deal()
        dealers_hand.add_card(dealers_card)
        
    # Create a list of the dealers card to enable showing only the first card    
        
    dealers_cards_list = str(dealers_hand).split("\n")
    

    # Set up the Player's chips
    
    players_chips = Chips()
    dealers_chips = Chips()
    
    
    # Prompt the Player for their bet
    
    current_bet = take_bet()
    print("")
    print("Bet Placed £",current_bet)
    
    
    # Show cards (but keep one dealer card hidden)
    print("")
    print("----------------")
    print("PLAYER,S HAND")
    print("")
    print(players_hand)
    print("Score of hand = ",players_hand.value)
    print("----------------")
    print("")
    print("----------------")
    print("DEALER,S HAND")
    print("")
    print(dealers_cards_list[0])
    print("")
    print("Score of hand = ",dealers_hand.value)
    print("----------------")
    
    player_playing = True
    bust = False
    
    while player_playing:  # recall this variable from our hit_or_stand function
        
        # Prompt for Player to Hit or Stand
        
        if "Y" == input("Enter Y to hit"):# or "y" == input("Enter Y to hit"):
            player_playing = True
        else:
            player_playing = False
            
        hit_or_stand(game_deck,players_hand)
        
        if players_hand.value > 21:
            bust = True
            player_playing = False
        
        # Show cards (but keep one dealer card hidden)
        print('--->Player_playing', player_playing)
        print('--->Bust', bust)
        print("")
        print("----------------")
        print("PLAYER,S HAND")
        print("")
        print(players_hand)
        print("Score of hand = ",players_hand.value)
        
    if bust == True:
        print ("you are bust")
    else:
        print("The dealers turn")
        
        # If player's hand exceeds 21, run player_busts() and break out of loop
        

            #break

    # If Player hasn't busted, play Dealer's hand until Dealer reaches 17
    
    
        # Show all cards
    
        # Run different winning scenarios
        
    
    # Inform Player of their chips total 
    
    # Ask to play again

        #break
    break
# Out:
# Blackjack game starting
# Place your bets!!678
#
# Bet Placed £ 678
#
# ----------------
# PLAYER,S HAND
#
# Ace of Hearts
# Seven of Hearts
#
# Score of hand =  18
# ----------------
#
# ----------------
# DEALER,S HAND
#
# Three of Hearts
#
# Score of hand =  13
# ----------------
# Enter Y to hitY
# HIT > New score after new card: 22
# >>adjust_for_ace: Prior to ran: hand.value:  22
# >>adjust_for_ace: After Ran selve.value>21 hand.value:  22
# Hand has 1 ace so subtract 10
# >>adjust_for_ace: After Ran else hand.value:  12
# HIT > after Adjust for Ace: 12
# ---->Hit_or_stand: hand.value 12
# --->Player_playing True
# --->Bust False
#
# ----------------
# PLAYER,S HAND
#
# Ace of Hearts
# Seven of Hearts
# Four of Hearts
#
# Score of hand =  12
# Enter Y to hitY
# HIT > New score after new card: 21
# >>adjust_for_ace: Prior to ran: hand.value:  21
# >>adjust_for_ace: After Ran else hand.value:  21
# HIT > after Adjust for Ace: 21
# ---->Hit_or_stand: hand.value 21
# ...

# %%
#For testing. Deals a card to player, adjusts for ace and prints hand and value

players_card = game_deck.deal()
players_hand.add_card(players_card)
players_hand.adjust_for_ace()
print(players_hand)
print ("Score of hand = ",players_hand.value)

dealers_card = game_deck.deal()
dealers_hand.add_card(dealers_card)
dealers_hand.adjust_for_ace()
print(dealers_hand)
print ("Score of hand = ",dealers_hand.value)
#print ("Score of last card",pauls_card.value)

# %%
#For testing. Creates a shuffled deck and instantiates the two hands.

game_deck = Deck()
game_deck.shuffle()
players_hand = Hand()
dealers_hand = Hand()

# %%
#_____________________________________________________________
#*************************************************************
#*************************************************************
#*************************************************************


















#_____________________________________________________________
