# %%
#More or less as copied from webpage, with image changed

#DO NOT ALTER, for reference, working version


import tkinter as tk

root = tk.Tk()

text1 = tk.Text(root, height=28, width=26)
photo = tk.PhotoImage(file='/home/nigel/Pack_of_cards/JD.gif')
text1.insert(tk.END, '\n')
text1.image_create(tk.END, image=photo)

text1.pack(side=tk.LEFT)

text2 = tk.Text(root, height=28, width=26)
scroll = tk.Scrollbar(root, command=text2.yview)
text2.configure(yscrollcommand=scroll.set)
text2.tag_configure('bold_italics', font=('Arial', 12, 'bold', 'italic'))
text2.tag_configure('big', font=('Verdana', 20, 'bold'))
text2.tag_configure('color',
                    foreground='#476042',
                    font=('Tempus Sans ITC', 12, 'bold'))
text2.tag_bind('follow',
               '<1>',
               lambda e, t=text2: t.insert(tk.END, "Not now, maybe later!"))
text2.insert(tk.END,'\nWilliam Shakespeare\n', 'big')
quote = """
To be, or not to be that is the question:
Whether 'tis Nobler in the mind to suffer
The Slings and Arrows of outrageous Fortune,
Or to take Arms against a Sea of troubles,
"""
text2.insert(tk.END, quote, 'color')
text2.insert(tk.END, 'follow-up\n', 'follow')
text2.pack(side=tk.LEFT)
scroll.pack(side=tk.RIGHT, fill=tk.Y)

root.mainloop()

# %%
#Working prog to display 2 cards


import tkinter as tk
from tkinter import *

root = tk.Tk()

root.geometry("1200x620+0+0")

canvas = Canvas(root, width = 300, height = 300)      
canvas.place(x=100, y=60)      
img = PhotoImage(file='/home/nigel/Pack_of_cards/5D.gif')      
canvas.create_image(0,0, anchor=NW, image=img)

canvas = Canvas(root, width = 300, height = 300)      
canvas.place(x=130, y=90)      
img2 = PhotoImage(file='/home/nigel/Pack_of_cards/JD.gif')      
canvas.create_image(0,0, anchor=NW, image=img2)      


#mainloop()    

root.mainloop()

# %%
#Working advanced version of above


import tkinter as tk
from tkinter import *

root = tk.Tk()

root.geometry("1200x620+0+0")


    
#input("press to continue")
disp_players_hand = [["","",100,60],["","",140,100],["","",180,140],["","",220,180],["","",260,220]]


disp_players_hand[0][1] = "5D.gif"
disp_players_hand[1][1] = "KC.gif"
disp_players_hand[2][1] = "2S.gif"
disp_players_hand[3][1] = "AH.gif"
disp_players_hand[4][1] = "3S.gif"

print(disp_players_hand[2][1])

img1 = PhotoImage(file='/home/nigel/Pack_of_cards/'+disp_players_hand[0][1])
img2 = PhotoImage(file='/home/nigel/Pack_of_cards/'+disp_players_hand[1][1])
img3 = PhotoImage(file='/home/nigel/Pack_of_cards/'+disp_players_hand[2][1])
img4 = PhotoImage(file='/home/nigel/Pack_of_cards/'+disp_players_hand[3][1])
img5 = PhotoImage(file='/home/nigel/Pack_of_cards/'+disp_players_hand[4][1])


#x=1

canvas = Canvas(root, width = 300, height = 300)      
canvas.place(x=disp_players_hand[0][2], y=disp_players_hand[0][3])            
canvas.create_image(0,0, anchor=NW, image=img1)

canvas = Canvas(root, width = 300, height = 300)      
canvas.place(x=disp_players_hand[1][2], y=disp_players_hand[1][3])           
canvas.create_image(0,0, anchor=NW, image=img2)

canvas = Canvas(root, width = 300, height = 300)      
canvas.place(x=disp_players_hand[2][2], y=disp_players_hand[2][3])           
canvas.create_image(0,0, anchor=NW, image=img3)

canvas = Canvas(root, width = 300, height = 300)      
canvas.place(x=disp_players_hand[3][2], y=disp_players_hand[3][3])           
canvas.create_image(0,0, anchor=NW, image=img4)

canvas = Canvas(root, width = 300, height = 300)      
canvas.place(x=disp_players_hand[4][2], y=disp_players_hand[4][3])           
canvas.create_image(0,0, anchor=NW, image=img5)



#mainloop()    

root.mainloop()

# %%
#Structuring above version to get it working in a program


import tkinter as tk
from tkinter import *

root = tk.Tk()

root.geometry("1200x620+0+0")


    
#input("press to continue")
disp_players_hand = [["","",100,60],["","",140,100],["","",180,140],["","",220,180],["","",260,220]]


disp_players_hand[0][1] = "5D.gif"
disp_players_hand[1][1] = "KC.gif"
disp_players_hand[2][1] = "2S.gif"
disp_players_hand[3][1] = "AH.gif"
disp_players_hand[4][1] = "JC.gif"

print(disp_players_hand[2][1])

img1 = PhotoImage(file='/home/nigel/Pack_of_cards/'+disp_players_hand[0][1])
img2 = PhotoImage(file='/home/nigel/Pack_of_cards/'+disp_players_hand[1][1])
img3 = PhotoImage(file='/home/nigel/Pack_of_cards/'+disp_players_hand[2][1])
img4 = PhotoImage(file='/home/nigel/Pack_of_cards/'+disp_players_hand[3][1])
img5 = PhotoImage(file='/home/nigel/Pack_of_cards/'+disp_players_hand[4][1])


#x=1

canvas = Canvas(root, width = 300, height = 300)      
canvas.place(x=disp_players_hand[0][2], y=disp_players_hand[0][3])            
canvas.create_image(0,0, anchor=NW, image=img1)

canvas = Canvas(root, width = 300, height = 300)      
canvas.place(x=disp_players_hand[1][2], y=disp_players_hand[1][3])           
canvas.create_image(0,0, anchor=NW, image=img2)

canvas = Canvas(root, width = 300, height = 300)      
canvas.place(x=disp_players_hand[2][2], y=disp_players_hand[2][3])           
canvas.create_image(0,0, anchor=NW, image=img3)

canvas = Canvas(root, width = 300, height = 300)      
canvas.place(x=disp_players_hand[3][2], y=disp_players_hand[3][3])           
canvas.create_image(0,0, anchor=NW, image=img4)

canvas = Canvas(root, width = 300, height = 300)      
canvas.place(x=disp_players_hand[4][2], y=disp_players_hand[4][3])           
canvas.create_image(0,0, anchor=NW, image=img5)



#mainloop()    

root.mainloop()
# Out:
# 2S.gif

# %%
from tkinter import Tk, Label, Button

class MyFirstGUI:
    def __init__(self, master):
        self.master = master
        master.title("A simple GUI")

        self.label = Label(master, text="This is our first GUI!")
        self.label.pack()

        self.greet_button = Button(master, text="Greet", command=self.greet)
        self.greet_button.pack()

        self.close_button = Button(master, text="Close", command=master.quit)
        self.close_button.pack()

    def greet(self):
        print("Greetings!")

root = Tk()
my_gui = MyFirstGUI(root)
my_next_gui = MyFirstGUI(root)
root.mainloop()

# %%
from tkinter import Tk, Label, Button
root = Tk()
root.mainloop()

# %%
import tkinter as tk
from tkinter import *

def dispcard(xpos,ypos,img):
    
    
    
    canvas = Canvas(root, width = 300, height = 300)      
    canvas.place(x=xpos, y=ypos)           
    canvas.create_image(0,0, anchor=NW, image=img)


root = tk.Tk()
root.geometry("1200x620+0+0")

img1 = PhotoImage(file='/home/nigel/Pack_of_cards/JD.gif')
dispcard(100,60,img1)

root.update

img2 = PhotoImage(file='/home/nigel/Pack_of_cards/3C.gif')
dispcard(140,100,img2)                  


root.mainloop()

print("Out of loop")
# Out:
# Out of loop

# %%
while True:
    ball.draw()
    tk.update_idletasks()
    tk.update()
