# %% [markdown]
# TASK: Notice how there is more than one page, and subsequent pages look like this http://quotes.toscrape.com/page/2/. Use what you know about for loops and string concatenation to loop through all the pages and get all the unique authors on the website. Keep in mind there are many ways to achieve this, also note that you will need to somehow figure out how to check that your loop is on the last page with quotes. For debugging purposes, I will let you know that there are only 10 pages, so the last page is http://quotes.toscrape.com/page/10/, but try to create a loop that is robust enough that it wouldn't matter to know the amount of pages beforehand, perhaps use try/except for this, its up to you!

# %% [markdown]
# TASKS: Compile a list of all authors on whole site
#
# 1. Create a soup for page 1
# 2. figure out how to select the authors for that soup
# 3. create a loop to fetch authors for all pages
#
# #EXAMPLE CODE
# result = requests.get("https://en.wikipedia.org/wiki/Napoleon")
# type(result)
# result.text
# soup = bs4.BeautifulSoup(result.text,"lxml")
# soup
# soup.select('h1')[0].getText()
# images = soup.select('.image')
# firstImage = images[0]
# firstImage['src']
# firstImage.keys()

# %%
# OUR TASK. Import request & beutiful soup
import requests
import bs4

def create_soup(url,tag_name):
    page = requests.get(url)
    soup = bs4.BeautifulSoup(page.text,"lxml")
    result = soup.select(tag_name)
    return result

def get_text_from_tag(tag_list):
    tag_number = len(tag_list)
    result = []
    for item in tag_list:
        result.append(item.getText())
    return result

def get_99_urls(url_template):
    result = []
    for item in range(1,99):
        result.append(url_template + str(item))
    return result
    
def our_page_scraper(url,tag_name):
    #Get 99 Urls
    imput_urls = get_99_urls(url)
    page_has_content = True
    master_result_list = []
     
    while page_has_content == True:
        for page_number in range(1,200):
            current_page = create_soup(imput_urls[page_number-1],tag_name)
            current_page_author_list = get_text_from_tag(current_page)

            if len(current_page_author_list) == 0:
                print('List is empty')
                page_has_content = False
                break  

            #print('Page Number',page_number)
            #print('Page Text:',current_page_author_list,'\n')
            # this is where we construct our master list of all records
            master_result_list = master_result_list + current_page_author_list
            #print('Page Text:',master_result_list,'\n')
            
    for item in master_result_list:
        print(item)
        
    return master_result_list

## NEXT STEPS
## we need to compile a master list of pages lists and then 
## generate one list to rule them all

# %%
our_page_scraper('http://quotes.toscrape.com/page/','.author')
#print('Our final output', our_list)
# Out:
# List is empty
# Albert Einstein
# J.K. Rowling
# Albert Einstein
# Jane Austen
# Marilyn Monroe
# Albert Einstein
# André Gide
# Thomas A. Edison
# Eleanor Roosevelt
# Steve Martin
# Marilyn Monroe
# J.K. Rowling
# Albert Einstein
# Bob Marley
# Dr. Seuss
# Douglas Adams
# Elie Wiesel
# Friedrich Nietzsche
# Mark Twain
# Allen Saunders
# Pablo Neruda
# Ralph Waldo Emerson
# Mother Teresa
# Garrison Keillor
# Jim Henson
# Dr. Seuss
# Albert Einstein
# J.K. Rowling
# Albert Einstein
# Bob Marley
# Dr. Seuss
# J.K. Rowling
# Bob Marley
# Mother Teresa
# J.K. Rowling
# Charles M. Schulz
# William Nicholson
# Albert Einstein
# Jorge Luis Borges
# George Eliot
# George R.R. Martin
# C.S. Lewis
# Marilyn Monroe
# Marilyn Monroe
# Albert Einstein
# Marilyn Monroe
# Marilyn Monroe
# Martin Luther King Jr.
# J.K. Rowling
# James Baldwin
# Jane Austen
# Eleanor Roosevelt
# Marilyn Monroe
# Albert Einstein
# Haruki Murakami
# Alexandre Dumas fils
# Stephenie Meyer
# Ernest Hemingway
# Helen Keller
# George Bernard Shaw
# Charles Bukowski
# Suzanne Collins
# Suzanne Collins
# C.S. Lewis
# J.R.R. Tolkien
# J.K. Rowling
# Ernest Hemingway
# Ralph Waldo Emerson
# Mark Twain
# Dr. Seuss
# Alfred Tennyson
# Charles Bukowski
# Terry Pratchett
# Dr. Seuss
# J.D. Salinger
# George Carlin
# John Lennon
# W.C. Fields
# Ayn Rand
# Mark Twain
# Albert Einstein
# Jane Austen
# J.K. Rowling
# Jane Austen
# Jane Austen
# C.S. Lewis
# C.S. Lewis
# Mark Twain
# Mark Twain
# C.S. Lewis
# J.K. Rowling
# Jimi Hendrix
# J.M. Barrie
# E.E. Cummings
# Khaled Hosseini
# Harper Lee
# Madeleine L'Engle
# Mark Twain
# Dr. Seuss
# George R.R. Martin
# ['Albert Einstein',
#  'J.K. Rowling',
#  'Albert Einstein',
#  'Jane Austen',
#  'Marilyn Monroe',
#  'Albert Einstein',
#  'André Gide',
#  'Thomas A. Edison',
#  'Eleanor Roosevelt',
#  'Steve Martin',
#  'Marilyn Monroe',
#  'J.K. Rowling',
#  'Albert Einstein',
#  'Bob Marley',
#  'Dr. Seuss',
#  'Douglas Adams',
#  'Elie Wiesel',
#  'Friedrich Nietzsche',
#  'Mark Twain',
#  'Allen Saunders',
#  'Pablo Neruda',
#  'Ralph Waldo Emerson',
#  'Mother Teresa',
#  'Garrison Keillor',
#  'Jim Henson',
#  'Dr. Seuss',
#  'Albert Einstein',
#  'J.K. Rowling',
#  'Albert Einstein',
#  'Bob Marley',
#  'Dr. Seuss',
#  'J.K. Rowling',
#  'Bob Marley',
#  'Mother Teresa',
#  'J.K. Rowling',
#  'Charles M. Schulz',
#  'William Nicholson',
#  'Albert Einstein',
#  'Jorge Luis Borges',
#  'George Eliot',
#  'George R.R. Martin',
#  'C.S. Lewis',
#  'Marilyn Monroe',
#  'Marilyn Monroe',
#  'Albert Einstein',
#  'Marilyn Monroe',
#  'Marilyn Monroe',
#  'Martin Luther King Jr.',
#  'J.K. Rowling',
#  'James Baldwin',
#  'Jane Austen',
#  'Eleanor Roosevelt',
#  'Marilyn Monroe',
#  'Albert Einstein',
#  'Haruki Murakami',
#  'Alexandre Dumas fils',
#  'Stephenie Meyer',
#  'Ernest Hemingway',
#  'Helen Keller',
#  'George Bernard Shaw',
#  'Charles Bukowski',
#  'Suzanne Collins',
#  'Suzanne Collins',
#  'C.S. Lewis',
#  'J.R.R. Tolkien',
#  'J.K. Rowling',
#  'Ernest Hemingway',
#  'Ralph Waldo Emerson',
#  'Mark Twain',
#  'Dr. Seuss',
#  'Alfred Tennyson',
#  'Charles Bukowski',
#  'Terry Pratchett',
#  'Dr. Seuss',
#  'J.D. Salinger',
#  'George Carlin',
#  'John Lennon',
#  'W.C. Fields',
#  'Ayn Rand',
#  'Mark Twain',
#  'Albert Einstein',
#  'Jane Austen',
#  'J.K. Rowling',
#  'Jane Austen',
#  'Jane Austen',
#  'C.S. Lewis',
#  'C.S. Lewis',
#  'Mark Twain',
#  'Mark Twain',
#  'C.S. Lewis',
#  'J.K. Rowling',
#  'Jimi Hendrix',
#  'J.M. Barrie',
#  'E.E. Cummings',
#  'Khaled Hosseini',
#  'Harper Lee',
#  "Madeleine L'Engle",
#  'Mark Twain',
#  'Dr. Seuss',
#  'George R.R. Martin']

# %%
all_authors = our_page_scraper('http://quotes.toscrape.com/page/','.author')
unique_authors = set(all_authors)
print('Unique Authors:', sorted(unique_authors))
# Out:
# List is empty
# Albert Einstein
# J.K. Rowling
# Albert Einstein
# Jane Austen
# Marilyn Monroe
# Albert Einstein
# André Gide
# Thomas A. Edison
# Eleanor Roosevelt
# Steve Martin
# Marilyn Monroe
# J.K. Rowling
# Albert Einstein
# Bob Marley
# Dr. Seuss
# Douglas Adams
# Elie Wiesel
# Friedrich Nietzsche
# Mark Twain
# Allen Saunders
# Pablo Neruda
# Ralph Waldo Emerson
# Mother Teresa
# Garrison Keillor
# Jim Henson
# Dr. Seuss
# Albert Einstein
# J.K. Rowling
# Albert Einstein
# Bob Marley
# Dr. Seuss
# J.K. Rowling
# Bob Marley
# Mother Teresa
# J.K. Rowling
# Charles M. Schulz
# William Nicholson
# Albert Einstein
# Jorge Luis Borges
# George Eliot
# George R.R. Martin
# C.S. Lewis
# Marilyn Monroe
# Marilyn Monroe
# Albert Einstein
# Marilyn Monroe
# Marilyn Monroe
# Martin Luther King Jr.
# J.K. Rowling
# James Baldwin
# Jane Austen
# Eleanor Roosevelt
# Marilyn Monroe
# Albert Einstein
# Haruki Murakami
# Alexandre Dumas fils
# Stephenie Meyer
# Ernest Hemingway
# Helen Keller
# George Bernard Shaw
# Charles Bukowski
# Suzanne Collins
# Suzanne Collins
# C.S. Lewis
# J.R.R. Tolkien
# J.K. Rowling
# Ernest Hemingway
# Ralph Waldo Emerson
# Mark Twain
# Dr. Seuss
# Alfred Tennyson
# Charles Bukowski
# Terry Pratchett
# Dr. Seuss
# J.D. Salinger
# George Carlin
# John Lennon
# W.C. Fields
# Ayn Rand
# Mark Twain
# Albert Einstein
# Jane Austen
# J.K. Rowling
# Jane Austen
# Jane Austen
# C.S. Lewis
# C.S. Lewis
# Mark Twain
# Mark Twain
# C.S. Lewis
# J.K. Rowling
# Jimi Hendrix
# J.M. Barrie
# E.E. Cummings
# Khaled Hosseini
# Harper Lee
# Madeleine L'Engle
# Mark Twain
# Dr. Seuss
# George R.R. Martin
# Unique Authors: ['Albert Einstein', 'Alexandre Dumas fils', 'Alfred Tennyson', 'Allen Saunders', 'André Gide', 'Ayn Rand', 'Bob Marley', 'C.S. Lewis', 'Charles Bukowski', 'Charles M. Schulz', 'Douglas Adams', 'Dr. Seuss', 'E.E. Cummings', 'Eleanor Roosevelt', 'Elie Wiesel', 'Ernest Hemingway', 'Friedrich Nietzsche', 'Garrison Keillor', 'George Bernard Shaw', 'George Carlin', 'George Eliot', 'George R.R. Martin', 'Harper Lee', 'Haruki Murakami', 'Helen Keller', 'J.D. Salinger', 'J.K. Rowling', 'J.M. Barrie', 'J.R.R. Tolkien', 'James Baldwin', 'Jane Austen', 'Jim Henson', 'Jimi Hendrix', 'John Lennon', 'Jorge Luis Borges', 'Khaled Hosseini', "Madeleine L'Engle", 'Marilyn Monroe', 'Mark Twain', 'Martin Luther King Jr.', 'Mother Teresa', 'Pablo Neruda', 'Ralph Waldo Emerson', 'Stephenie Meyer', 'Steve Martin', 'Suzanne Collins', 'Terry Pratchett', 'Thomas A. Edison', 'W.C. Fields', 'William Nicholson']
